# %% [markdown]
# <a href="https://colab.research.google.com/github/lorelourenco10-tech/programa-o-e-algor-timo-1f/blob/main/aula31_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estrutura de decisões

# Escrever um programa que recebe 02 números e reconhece o número maior.

# Entrada

numero1 = int (input("Digite um númeero: "))
numero2 = int (input("Digite um número: "))

# Processamento e saída

if numero1 > numero2:
  print (f"O número {numero1} é maior que o número {numero2}.")

else: print (f"O número {numero1} é menor que o número {numero2}.")
# Out:
# Digite um númeero: 9
# Digite um número: 2
# O número 9 é maior que o número 2.

# %%
# Entrada

numero1 = int (input("Digite um númeero: "))
numero2 = int (input("Digite um número: "))

# Processamento e saída

if numero1 > numero2:
  print (f"O número {numero1} é maior que o número {numero2}.")

elif numero1 == numero2:
  print (f"O número {numero1} é igual ao número {numero2}.")

else: print (f"O número {numero1} é menor que o número {numero2}.")
# Out:
# Digite um númeero: 1977
# Digite um número: 1977
# O número 1977 é igual ao número 1977.

# %%
# Escrever um programa que o usuário digita seu nome e idade

# Identificação de nome e idade

# Entrada

# > que 12 criança
# > que 18 adolescente
# < que 18 adulto

nome = str (input("Digite seu primeiro nome: "))
idade = int (input("Digite sua idade: "))

# Processamento e saída

if idade <= 12:
  print (f"Você é uma criança.")

elif idade > 12:
  print (f"Você é um adolescente.")

else:
  print (f"Você é adulto. ")
# Out:
# Digite seu primeiro nome: Lorena
# Digite sua idade: 15
# Você é um adolescente.
