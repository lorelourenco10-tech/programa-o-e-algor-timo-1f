# %% [markdown]
# <a href="https://colab.research.google.com/github/lorelourenco10-tech/programa-o-e-algor-timo-1f/blob/main/AULA_26_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculadora simples

#  o programa recebera dois numeros e realizar uma das quatro operaçoes matematicas

OPCAO = ""
numero_a = 0
numero_b = 0

print("------MENU-------")
print("")
print("OPÇÃO 1 SOMAR")
print("OPÇÃO 2 SUBTRAÇÃO")
print("OPÇÃO 3 MULTIPLICAÇÃO")
print(" OPÇÃO 4 DIVISÃO")
print("OPÇAO 5 SAIR")
print("------------------")


while OPCAO != 5:
  OPCAO= int (input("Digite a opção desejada ou 5 para sair: "))

  if OPCAO ==1 :
    numero_a = float(input("Digite um número: "))
    numero_b = float(input("Digite um número: "))

    print(f" O total da soma de {numero_a} + {numero_b} é igual : {numero_a + numero_b}")


  elif OPCAO == 2:
    numero_a = float(input("Digite um número: "))
    numero_b = float(input("Digite um número: "))

    print(f"O total da subtração de {numero_a} - {numero_b} é igual : {numero_a - numero_b}")

  elif OPCAO == 3:
    numero_a = float(input("Digite um número: "))
    numero_b = float(input("Digite um número: "))

    print(f"O total da multiplicação de {numero_a} x {numero_b} é igual : {numero_a * numero_b}")

  elif OPCAO ==4:
    numero_a = float(input("Digite um número: "))
    numero_b = float(input("Digite um número: "))

    print(f"O total da divisão de {numero_a} / {numero_b} é igual : {numero_a / numero_b}")
    print("")
# Out:
# ------MENU-------
#
# OPÇÃO 1 SOMAR
# OPÇÃO 2 SUBTRAÇÃO
# OPÇÃO 3 MULTIPLICAÇÃO
#  OPÇÃO 4 DIVISÃO
# OPÇAO 5 SAIR
# ------------------
# Digite a opção desejada ou 5 para sair: 4
# Digite um número: 6
# Digite um número: 3
# O total da divisão de 6.0 / 3.0 é igual : 2.0
#
# Digite a opção desejada ou 5 para sair: 5

# %%
# Projeto caixa eletrônico

# Você foi contratado para desenvolver um sistema simples de caixa eletrônico

# O sistema deverá funcionar através de um menu interativo utilizando o "while"

# O programa deve iniciar com um saldo inicial de R$1000,00 e permitir que o usuário escolha diferentes operações até decidir sair do sistema

# Ver saldo
# Depositar
# Sacar Dinheiro
# Sair

# Regras:

# Quando depositar somar ao saldo anterior;
# Quando sacar subtrair so salário anterior;
# Mostrar o saldo para o usuário.
