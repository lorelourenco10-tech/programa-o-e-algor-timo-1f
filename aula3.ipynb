# %% [markdown]
# <a href="https://colab.research.google.com/github/lorelourenco10-tech/programa-o-e-algor-timo-1f/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1 = 2
lado2 = 3

# cálculo da área

area = lado1 * lado2

# cálculo da área de um quadrado

areaquadrado = lado1 * lado1

# %%
print (area)
# Out:
# 6

# %%
print (areaquadrado)
# Out:
# 4

# %%
nome = "Lorena"
idade = 15
altura = 1.6

# %%
print (nome)
# Out:
# Lorena

# %%
print (idade)
# Out:
# 15

# %%
print (altura)
# Out:
# 1.6

# %%
print (f"nome : {nome}, idade : {idade}, altura : {altura}")
# Out:
# nome : Lorena, idade : 15, altura : 1.6
